plot(basetestes$Total, type="s")
# Out:
# plot without title

# %%
install.packages('forecast')
# Out:
# also installing the dependencies 'quadprog', 'fracdiff', 'lmtest', 'tseries', 'urca', 'RcppArmadillo'
#   There are binary versions available but the source versions are later:
#                   binary     source needs_compilation
# tseries          0.10-53    0.10-54              TRUE
# RcppArmadillo 0.12.2.0.0 0.12.6.6.0              TRUE
# forecast            8.21     8.21.1              TRUE
#
#   Binaries will be installed
# package 'quadprog' successfully unpacked and MD5 sums checked
# package 'fracdiff' successfully unpacked and MD5 sums checked
# package 'lmtest' successfully unpacked and MD5 sums checked
# package 'tseries' successfully unpacked and MD5 sums checked
# package 'urca' successfully unpacked and MD5 sums checked
# package 'RcppArmadillo' successfully unpacked and MD5 sums checked
# package 'forecast' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rlnet\AppData\Local\Temp\RtmpEfBtfU\downloaded_packages

# %%
library('forecast')
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
mod <- holt(base$Total)
mod
# Out:
#     Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# 134       10.41452 10.37009 10.45894 10.34658 10.48246
# 135       10.51603 10.43109 10.60098 10.38612 10.64595
# 136       10.61755 10.48605 10.74906 10.41643 10.81867
# 137       10.71907 10.53530 10.90284 10.43801 11.00013
# 138       10.82059 10.57930 11.06187 10.45157 11.18960
# 139       10.92210 10.61846 11.22575 10.45772 11.38649
# 140       11.02362 10.65310 11.39414 10.45696 11.59028
# 141       11.12514 10.68351 11.56676 10.44973 11.80054
# 142       11.22665 10.70992 11.74339 10.43638 12.01693
# 143       11.32817 10.73253 11.92382 10.41721 12.23913

# %%
mod2 <- holt(base['4D'])
mod2
# Out:
# Error in holt(base["4D"]): I need at least two observations to estimate trend.
# Traceback:
#
# 1. holt(base["4D"])
# 2. stop("I need at least two observations to estimate trend.")

# %%
plot(basetestes$Total, type="s")
# Out:
# plot without title

# %%
plot(basetestes$Total, type="s")
lines(fitted(mod), col='blue')
# Out:
# plot without title

# %%
lines(fitted(mod), col='blue')
# Out:
# Error in plot.xy(xy.coords(x, y), type = type, ...): plot.new has not been called yet
# Traceback:
#
# 1. lines(fitted(mod), col = "blue")
# 2. lines.ts(fitted(mod), col = "blue")
# 3. lines.default(time(as.ts(x)), x, ...)
# 4. plot.xy(xy.coords(x, y), type = type, ...)

# %%
forecast(mod, h=10)
# Out:
#     Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# 134       10.41452 10.37009 10.45894 10.34658 10.48246
# 135       10.51603 10.43109 10.60098 10.38612 10.64595
# 136       10.61755 10.48605 10.74906 10.41643 10.81867
# 137       10.71907 10.53530 10.90284 10.43801 11.00013
# 138       10.82059 10.57930 11.06187 10.45157 11.18960
# 139       10.92210 10.61846 11.22575 10.45772 11.38649
# 140       11.02362 10.65310 11.39414 10.45696 11.59028
# 141       11.12514 10.68351 11.56676 10.44973 11.80054
# 142       11.22665 10.70992 11.74339 10.43638 12.01693
# 143       11.32817 10.73253 11.92382 10.41721 12.23913
